# %%
pip install matplotlib requests telethon
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: telethon in c:\users\matarwy\appdata\roaming\python\python39\site-packages (1.28.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: pyaes in c:\users\matarwy\appdata\roaming\python\python39\site-packages (from telethon) (1.6.1)
# Requirement already satisfied: rsa in c:\users\matarwy\appdata\roaming\python\python39\site-packages (from telethon) (4.9)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\programdata\anaconda3\lib\site-packages (from rsa->telethon) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
from helpers import *

CONFIG = read_crypto_data('config.json')
API_KEY = CONFIG['CMC_API_KEY']
TE_API_ID = CONFIG['TELEGRAM_API_ID']
TE_API_HASH = CONFIG['TELEGRAM_API_HASH']
TE_PHONE = CONFIG['TELEGRAM_PHONE']
new_coins_data = get_new_coin(API_KEY)
for(i, coin) in enumerate(new_coins_data['data']):
    print(f"{i+1}. {coin['name']} ({coin['symbol']}) ({coin['id']})")
# Out:
# 1. Omega Network (OMN) (23877)
# 2. ToxicGarden.finance SEED (SEED) (27032)
# 3. X Project (X-TOKEN) (27031)
# 4. ELSD Coin (ELSD) (27030)
# 5. TLSD Coin (TLSD) (27029)
# 6. XLSD Coin (XLSD) (27028)
# 7. What Do You Meme (WDYM) (27027)
# 8. Pep ManCity (PEPMCITY) (27025)
# 9. DISAPPOINTED DAD (DAD) (27024)
# 10. FOOM (FOOM) (27023)
# 11. Popcat (POPCAT) (27022)
# 12. Pre Pepe Days (PREPE) (27021)
# 13. Jack AI (JACK) (27020)
# 14. Jesus-Raptor (RAPTOR) (27019)
# 15. BNBDragon (BNBDRGN) (27018)
# 16. CreamPAI (PAI) (27017)
# 17. Gates of Valhalla (GOV) (27016)
# 18. DZD (DZD) (27014)
# 19. T-rexUnicornUFOSushiWomanSmokingAtomInu (ELON) (27013)
# 20. Trex Buddha (TREX) (27011)
# 21. Tribalisland Token (TIT) (27010)
# 22. UniBot (UNIBOT) (27009)
# 23. 0xGasless (0XGAS) (27008)
# 24. EMDX (EMDX) (27007)
# 25. PEPE Wrestling (PEPEWWE) (27005)
# 26. GOGU Coin (GOGU) (27002)
# 27. Whaleclub (WC) (27001)
# 28. Christopher Poole (MOOT) (26999)
# 29. Meditation3 (MEDIT) (26841)
# 30. AI Meta Club (AMC) (26135)
# 31. Statter Network (STT) (26914)
# 32. Revive (REVIVE) (26995)
# 33. SMILEY (SMILEY) (26994)
# 34. YabbaDabbaDoo (DOO) (26993)
# 35. The Flash (FLASH) (26991)
# 36. QMGF (QMGF) (26990)
# 37. BERLUSCONI ($SILVIO) (26989)
# 38. Token (TOKEN) (26988)
# 39. David (DAVID) (26987)
# 40. Elon Floki CEO (ELONFLOKI) (26986)
# 41. NAUGHTY QUAGMIRE (NQUAG) (26985)
# 42. Red-Eyed-Frog (REEY) (26983)
# 43. AI-X (X) (26984)
# 44. TrumpPepe (TRUMPPEPE) (26981)
# 45. Votecoin (VOTE) (26980)
# 46. ROBO PEPE (ROBOPEPE) (26978)
# 47. ShenZhou16 (SHENZHOU) (26977)
# 48. Homeety (HOM) (26973)
# 49. REAPER (REAPER) (26972)
# 50. Nite Network (NITE) (26971)
# 51. GrabCoinClub (GC) (26960)
# 52. Garuda Coin (GARU) (26852)
# 53. GOCHAN COIN (GOCHAN) (26970)
# 54. Rotate (ROTATE) (26969)
# 55. The Joker Coin (JOKER) (26968)
# 56. zkSync Labs (ZKLAB) (26967)
# 57. Tucker Carlson (TUCKER) (26966)
# 58. RevivalDeFi (REVDEFI) (26965)
# 59. BabyHkTiger (BABYHKTIGER) (26964)
# 60. Gudetama (TAMA) (26963)
# 61. Sideshow Bob (BOB) (26962)
# 62. Koduck (KLD) (26961)
# 63. OtterHome (HOME) (26959)
# 64. Champignons of Arborethia (CHAMPZ) (26958)
# 65. Insurabler (INSR) (26957)
# 66. Math Coin (MATH) (26956)
# 67. MESSI COIN (MESSI) (26955)
# 68. FoxGPT (FGPT) (26921)
# 69. Paladeum (PLB) (26954)
# 70. Fat Pickle (FATP) (26953)
# 71. Suiswap (SSWP) (26952)
# 72. QunatumXC (QXC) (26951)
# 73. Candy Pocket (CANDY) (26858)
# 74. Neutron (NTRN) (26680)
# 75. Moses Coin (MOSES) (26949)
# 76. CopyCat DAO (CCD) (26948)
# 77. Cheese (CHEESE) (26947)
# 78. Phantom (PHANTOM) (26946)
# 79. Guan Yu (GUAN YU) (26945)
# 80. Reddit (REDDIT) (26944)
# 81. Redemit (REDEMIT) (26943)
# 82. Kid Goku (KIDGOKU) (26942)
# 83. SHKEK (SHKEK) (26941)
# 84. Pepe Classic (PEPC) (26940)
# 85. Sonic Space Cat (SCAT) (26939)
# 86. CaptainAmerica (CAPT) (26937)
# 87. Spider Spirit (SPIDER) (26936)
# 88. Streakk Chain (STKC) (26935)
# 89. CryptHub (CRHT) (26932)
# 90. Fuck Stupid Egotistical Cocksuckers (FSEC) (26931)
# 91. MetaXRC (MXRC) (26930)
# 92. UFO Coin (UFO) (26929)
# 93. FUFU Coin (FUFU) (26928)
# 94. Proof of Anon (0XPROOF) (26927)
# 95. BananaceV2 (NANA) (26926)
# 96. Dogeclub (DOGC) (26925)
# 97. BABYLTC (BLTC) (26924)
# 98. Jesus (RAPTOR) (26923)
# 99. ZangAi (ZANGAI) (26922)
# 100. BabyAMA (BAMA) (26920)

# %%
# Get Price Change Percent Data
coin_id_in = input("Please Enter COIN ID: ")
for coin in new_coins_data['data']:
    if coin['id'] == int(coin_id_in):
        print(f"Price Change for {coin['name']} ({coin['symbol']}) ({coin['id']})")
        get_price_change(API_KEY, coin['id'], coin['quote']['USD']['price'])
        break
# Out:
# Please Enter COIN ID: 26920
# Price Change for BabyAMA (BAMA) (26920)
# (5m) -0.19%
# (10m) -0.24%
# (30m) -0.38%
# (24h) 2.03%
# (7d) -0.09%
# (30d) -0.09%

# %%
# Get Price Moving Average Data
coin_id_in = input("Please Enter COIN ID: ")
window1 = int(input("Enter Window Size Period 1: "))
window2 = int(input("Enter Window Size Period 2: "))
window3 = int(input("Enter Window Size Period 3: "))
for coin in new_coins_data['data']:
    if coin['id'] == int(coin_id_in):
        mva1 = get_moving_average(API_KEY, coin['id'], window1)
        mva2 = get_moving_average(API_KEY, coin['id'], window2)
        mva3 = get_moving_average(API_KEY, coin['id'], window3)
        print(f"Moving Average for {coin['name']} ({coin['symbol']}) ({coin['id']})")
        plot_price_with_moving_average(mva1, mva2, mva3, window1, window2, window3)
        break
# Out:
# Please Enter COIN ID: 26920
# Enter Window Size Period 1: 10
# Enter Window Size Period 2: 30
# Enter Window Size Period 3: 50
# Moving Average for BabyAMA (BAMA) (26920)

# %%
# Get Telegram Messages Data
coin_id_in = input("Please Enter COIN ID: ")
for coin in new_coins_data['data']:
    if coin['id'] == int(coin_id_in):
        msgcounts = await get_telegram_chat(API_KEY, TE_API_ID, TE_API_HASH, TE_PHONE, coin['id'])
        plot_telegram_chat(msgcounts)
        break
